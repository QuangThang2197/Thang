# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoang-Quang-Thang/Thang/blob/main/Thang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Tải 1 url về

# %%
from bs4 import BeautifulSoup
import requests
import os

# %%
url = 'https://vietnamnet.vn/'

# %%
page = requests.get(url)
print(page)
page.text
# Out:
# <Response [200]>
# ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="vi">
#  <head>
#   <script language="javascript" src="https://vnn-res.vgcloud.vn/ResV9/js/startup-2019-v003.js">
#   </script>
#   <script type="text/javascript">
#    var globalads_off=false;
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="https://vnn-res.vgcloud.vn/ResV9/images/faviconvnn2018.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Báo VietNamNet - Tin tức online, tin nhanh Việt Nam và thế giới
#   </title>
#   <meta content="Đọc báo điện tử VietNamNet, cập nhật tin nhanh Việt Nam và thế giới. Sự kiện, tin báo mới trong ngày, kinh tế, xã hội, pháp luật 24h qua." name="description"/>
#   <meta content="tin tức, tin tức online, đọc báo, báo, tin, tin nhanh, vietnamnet" name="keywords"/>
#   <meta content="tin tức, tin tức online, đọc báo, báo, tin, tin nhanh, vietnamnet" name="news_keywords"/>
# ...

# %% [markdown]
# 2. Lưu 1 html vào thư mục chỉ định

# %%
file = 'url_list' + 'html'
f = open(file, 'w')
f.write(link.text)
f.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# 3. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list

# %%
list = [1, 2, 3, 4]
x = list.pop(0)
print(x)
print(list)

# %% [markdown]
# 4. Cách lấy các url trong html

# %%
for link in soup.find_all('a'):
  if 'href' in link.attrs:
    print(link.attrs['href'])
# Out:
# /
# https://vietnamnet.vn/vn/thoi-su/dai-hoi-dang-lan-thu-xiii/
# #
# /vn/tin-moi-nong/
# /vn/tin-tuc-24h/
# https://www.facebook.com/vietnamnet.vn
# https://www.youtube.com/vietnamnetofficial
# javascript:void(0)
# javascript:void(0)
# https://id.vietnamnet.vn/Home.html
# javascript:void(0)
# /
# /vn/thoi-su/chinh-tri/
# /vn/talkshow/
# /vn/thoi-su/
# /vn/thoi-su/chong-tham-nhung/
# /vn/thoi-su/quoc-hoi/
# /vn/thoi-su/an-toan-giao-thong/
# /vn/thoi-su/moi-truong/
# /vn/thoi-su/clip-nong/
# /vn/thoi-su/bhxh-bhyt/
# /vn/thoi-su/quoc-phong/
# /vn/kinh-doanh/
# /vn/kinh-doanh/tai-chinh/
# /vn/kinh-doanh/dau-tu/
# /vn/kinh-doanh/thi-truong/
# /vn/kinh-doanh/doanh-nhan/
# /vn/kinh-doanh/tu-van-tai-chinh/
# /vn/kinh-doanh/Amaccao/
# /vn/giai-tri/
# /vn/giai-tri/the-gioi-sao/
# /vn/giai-tri/thoi-trang/
# /vn/giai-tri/nhac/
# /vn/giai-tri/phim/
# /vn/giai-tri/truyen-hinh/
# /vn/giai-tri/sach/
# /vn/giai-tri/di-san-my-thuat-san-khau/
# /vn/the-gioi/
# /vn/the-gioi/binh-luan-quoc-te/
# ...
